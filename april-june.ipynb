# %%
import pandas as pd


aq1701_1801=pd.read_csv('airq1701_1801_longlat.csv',index_col=0)

aq1701_1801.isnull().sum()
# Out:
# stationId        0
# utc_time         0
# PM2.5        20389
# PM10         83263
# NO2          18651
# CO           42813
# O3           20421
# SO2          18548
# longitude        0
# latitude         0
# dtype: int64

# %%
aq180203=pd.read_csv('airQuality_201802-201803.csv')

# %%
columns = aq180203.columns
percent_missing = aq180203.isnull().sum() * 100 / len(aq180203)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#           column_name  percent_missing
# stationId   stationId         0.000000
# utc_time     utc_time         0.000000
# PM2.5           PM2.5         6.212060
# PM10             PM10        26.127074
# NO2               NO2         6.210036
# CO                 CO         6.740186
# O3                 O3         6.699717
# SO2               SO2         6.305140

# %%
aq1804=pd.read_csv('airQuality_201804.csv')

# %%
columns = aq1804.columns
percent_missing = aq1804.isnull().sum() * 100 / len(aq1804)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                            column_name  percent_missing
# id                                  id         0.000000
# station_id                  station_id         0.000000
# time                              time         0.000000
# PM25_Concentration  PM25_Concentration         5.298155
# PM10_Concentration  PM10_Concentration        20.956671
# NO2_Concentration    NO2_Concentration         4.495924
# CO_Concentration      CO_Concentration         4.483054
# O3_Concentration      O3_Concentration         5.113685
# SO2_Concentration    SO2_Concentration         4.401544

# %%
duplicated=[]
aq1701_1801['duplicated'] = aq1701_1801.duplicated()

for i in aq1701_1801['duplicated']:
    #print(i)
    if i==True:
        duplicated.append(i)
len(duplicated)
# Out:
# 6475

# %% [markdown]
# # Check missing values

# %%
columns = aq1701_1801.columns
percent_missing = aq1701_1801.isnull().sum() * 100 / len(aq1701_1801)
missing_value_df = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#            column_name  percent_missing
# stationId    stationId         0.000000
# utc_time      utc_time         0.000000
# PM2.5            PM2.5         6.555738
# PM10              PM10        26.771808
# NO2                NO2         5.996913
# CO                  CO        13.765795
# O3                  O3         6.566027
# SO2                SO2         5.963795
# longitude    longitude         0.000000
# latitude      latitude         0.000000
# duplicated  duplicated         0.000000

# %%
aq1802=pd.read_csv('airQuality_201802-201803.csv',index_col=0)

aq1802.isnull().sum()
# Out:
# utc_time        0
# PM2.5        3070
# PM10        12912
# NO2          3069
# CO           3331
# O3           3311
# SO2          3116
# dtype: int64

# %%
columns = aq1802.columns
percent_missing2 = aq1802.isnull().sum() * 100 / len(aq1802)
missing_value_df2 = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing2})
missing_value_df2
# Out:
#          column_name  percent_missing
# utc_time    utc_time         0.000000
# PM2.5          PM2.5         6.212060
# PM10            PM10        26.127074
# NO2              NO2         6.210036
# CO                CO         6.740186
# O3                O3         6.699717
# SO2              SO2         6.305140

# %%
aq1804=pd.read_csv('airQuality_201804.csv',index_col=0)

aq1804.isnull().sum()
# Out:
# station_id               0
# time                     0
# PM25_Concentration    1235
# PM10_Concentration    4885
# NO2_Concentration     1048
# CO_Concentration      1045
# O3_Concentration      1192
# SO2_Concentration     1026
# dtype: int64

# %%
columns = aq1804.columns
percent_missing3 = aq1804.isnull().sum() * 100 / len(aq1804)
missing_value_df3 = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing3})
missing_value_df3
# Out:
#                            column_name  percent_missing
# station_id                  station_id         0.000000
# time                              time         0.000000
# PM25_Concentration  PM25_Concentration         5.298155
# PM10_Concentration  PM10_Concentration        20.956671
# NO2_Concentration    NO2_Concentration         4.495924
# CO_Concentration      CO_Concentration         4.483054
# O3_Concentration      O3_Concentration         5.113685
# SO2_Concentration    SO2_Concentration         4.401544

# %% [markdown]
# # Select time from april to june

# %%
df = aq1701_1801[(aq1701_1801['utc_time'] >='2017-04-01 00:00')& (aq1701_1801['utc_time'] < '2017-07-01 00:00')]
df[4000:]
# Out:
#             stationId             utc_time  PM2.5   PM10   NO2   CO     O3  \
# 20100   beibuxinqu_aq  2017-04-15 12:00:00   30.0  100.0  18.0  0.3  128.0
# 20101   beibuxinqu_aq  2017-04-15 13:00:00   36.0   98.0  18.0  0.3  121.0
# 20102   beibuxinqu_aq  2017-04-15 14:00:00   22.0   94.0  28.0  0.3   93.0
# 20103   beibuxinqu_aq  2017-04-15 15:00:00   45.0   98.0  37.0  0.5   53.0
# 20104   beibuxinqu_aq  2017-04-15 16:00:00   31.0  100.0  53.0  0.5   19.0
# 20105   beibuxinqu_aq  2017-04-15 17:00:00   33.0   79.0  80.0  0.5    2.0
# 20106   beibuxinqu_aq  2017-04-15 18:00:00   42.0   89.0  87.0  0.6    2.0
# 20107   beibuxinqu_aq  2017-04-15 19:00:00   35.0  114.0  79.0  0.6    2.0
# 20108   beibuxinqu_aq  2017-04-15 20:00:00   27.0   89.0  74.0  0.6    2.0
# 20109   beibuxinqu_aq  2017-04-15 21:00:00   33.0   81.0  62.0  0.6    2.0
# 20110   beibuxinqu_aq  2017-04-15 22:00:00   30.0   69.0  66.0  0.7    2.0
# ...

# %%
df.to_csv('airq1704_1706_longlat.csv',index=False)
df.head(5)
# Out:
#             stationId             utc_time  PM2.5  PM10   NO2   CO    O3  SO2  \
# 1980  aotizhongxin_aq  2017-04-01 00:00:00   16.0  50.0  60.0  0.4  17.0  2.0
# 1981  aotizhongxin_aq  2017-04-01 01:00:00   18.0  59.0  54.0  0.4  25.0  4.0
# 1982  aotizhongxin_aq  2017-04-01 02:00:00   16.0  41.0  43.0  0.4  36.0  3.0
# 1983  aotizhongxin_aq  2017-04-01 03:00:00   18.0  28.0  26.0  0.3  54.0  5.0
# 1984  aotizhongxin_aq  2017-04-01 04:00:00    7.0  31.0  26.0  0.3  58.0  4.0
#
#       longitude  latitude  duplicated
# 1980    116.397    39.982       False
# 1981    116.397    39.982       False
# 1982    116.397    39.982       False
# 1983    116.397    39.982       False
# 1984    116.397    39.982       False

# %% [markdown]
# # Observedweather

# %%
ob=pd.read_csv('observedWeather_201701-201801.csv')
ob.head(5)
# Out:
#    station_id   longitude   latitude             utc_time  temperature  \
# 0  shunyi_meo  116.615278  40.126667  2017-01-30 16:00:00         -1.7
# 1  shunyi_meo  116.615278  40.126667  2017-01-30 17:00:00         -3.5
# 2  shunyi_meo  116.615278  40.126667  2017-01-30 18:00:00         -3.7
# 3  shunyi_meo  116.615278  40.126667  2017-01-30 19:00:00         -3.9
# 4  shunyi_meo  116.615278  40.126667  2017-01-30 20:00:00         -4.1
#
#    pressure  humidity  wind_direction  wind_speed      weather
# 0    1028.7        15           215.0         1.6  Sunny/clear
# 1    1028.4        24            16.0         1.0         Haze
# 2    1028.1        27            32.0         1.1         Haze
# 3    1027.6        27            21.0         0.9         Haze
# 4    1026.7        26            17.0         1.1         Haze

# %%
columns = ob.columns
percent_missing4 = ob.isnull().sum() * 100 / len(ob)
missing_value_df4 = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing4})
missing_value_df4
# Out:
#                    column_name  percent_missing
# station_id          station_id         0.000000
# longitude            longitude         0.000000
# latitude              latitude         0.000000
# utc_time              utc_time         0.000000
# temperature        temperature         0.000000
# pressure              pressure         0.000000
# humidity              humidity         0.000000
# wind_direction  wind_direction         0.148057
# wind_speed          wind_speed         0.148057
# weather                weather         0.000000

# %%
df2 = ob[(ob['utc_time'] >='2017-04-01 00:00:00')& (ob['utc_time'] <= '2017-06-30 23:00:00')]
#df2=df2.drop('weather',axis=1)
df2.head(5)
# Out:
#       station_id   longitude   latitude             utc_time  temperature  \
# 1448  shunyi_meo  116.615278  40.126667  2017-04-01 00:00:00         10.7
# 1449  shunyi_meo  116.615278  40.126667  2017-04-01 01:00:00         13.5
# 1450  shunyi_meo  116.615278  40.126667  2017-04-01 02:00:00         16.2
# 1451  shunyi_meo  116.615278  40.126667  2017-04-01 03:00:00         19.0
# 1452  shunyi_meo  116.615278  40.126667  2017-04-01 04:00:00         18.9
#
#       pressure  humidity  wind_direction  wind_speed      weather
# 1448    1015.8        32           342.0         0.8  Sunny/clear
# 1449    1015.7        22             6.0         1.8  Sunny/clear
# 1450    1015.1        17           359.0         1.0  Sunny/clear
# 1451    1014.0        14           159.0         1.2  Sunny/clear
# 1452    1013.1        14           230.0         1.5  Sunny/clear

# %%
df2.to_csv('observedWeather1704-1706.csv')
df2.head(5)
# Out:
#       station_id   longitude   latitude             utc_time  temperature  \
# 1448  shunyi_meo  116.615278  40.126667  2017-04-01 00:00:00         10.7
# 1449  shunyi_meo  116.615278  40.126667  2017-04-01 01:00:00         13.5
# 1450  shunyi_meo  116.615278  40.126667  2017-04-01 02:00:00         16.2
# 1451  shunyi_meo  116.615278  40.126667  2017-04-01 03:00:00         19.0
# 1452  shunyi_meo  116.615278  40.126667  2017-04-01 04:00:00         18.9
#
#       pressure  humidity  wind_direction  wind_speed      weather
# 1448    1015.8        32           342.0         0.8  Sunny/clear
# 1449    1015.7        22             6.0         1.8  Sunny/clear
# 1450    1015.1        17           359.0         1.0  Sunny/clear
# 1451    1014.0        14           159.0         1.2  Sunny/clear
# 1452    1013.1        14           230.0         1.5  Sunny/clear

# %% [markdown]
# # GridWeather

# %%
grid=pd.read_csv('gridWeather_201701-201803.csv')
grid.head(5)
# Out:
#         stationName  longitude  latitude             utc_time  temperature  \
# 0  beijing_grid_000      115.0      39.0  2017-01-01 00:00:00        -5.47
# 1  beijing_grid_001      115.0      39.1  2017-01-01 00:00:00        -5.53
# 2  beijing_grid_002      115.0      39.2  2017-01-01 00:00:00        -5.70
# 3  beijing_grid_003      115.0      39.3  2017-01-01 00:00:00        -5.88
# 4  beijing_grid_004      115.0      39.4  2017-01-01 00:00:00        -5.34
#
#    pressure  humidity  wind_direction  wind_speed/kph
# 0    984.73     76.60           53.71            3.53
# 1    979.33     75.40           43.59            3.11
# 2    963.14     71.80            0.97            2.75
# 3    946.94     68.20          327.65            3.84
# 4    928.80     58.81          317.85            6.14

# %%
columns = grid.columns
percent_missing5 = grid.isnull().sum() * 100 / len(grid)
missing_value_df5 = pd.DataFrame({'column_name': columns,
                                 'percent_missing': percent_missing5})
missing_value_df5
# Out:
#                    column_name  percent_missing
# stationName        stationName              0.0
# longitude            longitude              0.0
# latitude              latitude              0.0
# utc_time              utc_time              0.0
# temperature        temperature              0.0
# pressure              pressure              0.0
# humidity              humidity              0.0
# wind_direction  wind_direction              0.0
# wind_speed/kph  wind_speed/kph              0.0

# %%
df3 = grid[(grid['utc_time'] >='2017-04-01 00:00:00')& (grid['utc_time'] <= '2017-06-30 23:00:00')]
df3.head(5)
# Out:
#               stationName  longitude  latitude             utc_time  \
# 1406160  beijing_grid_000      115.0      39.0  2017-04-01 00:00:00
# 1406161  beijing_grid_001      115.0      39.1  2017-04-01 00:00:00
# 1406162  beijing_grid_002      115.0      39.2  2017-04-01 00:00:00
# 1406163  beijing_grid_003      115.0      39.3  2017-04-01 00:00:00
# 1406164  beijing_grid_004      115.0      39.4  2017-04-01 00:00:00
#
#          temperature  pressure  humidity  wind_direction  wind_speed/kph
# 1406160        10.55    980.06     28.80          307.92           12.59
# 1406161        10.31    974.89     28.83          307.06           12.61
# 1406162         9.58    959.35     28.91          304.48           12.65
# 1406163         8.85    943.82     29.00          301.94           12.73
# 1406164         7.65    926.03     30.24          305.52           13.15

# %%
df3.to_csv('gridWeather1704-1706.csv')
df3.head(5)
# Out:
#               stationName  longitude  latitude             utc_time  \
# 1406160  beijing_grid_000      115.0      39.0  2017-04-01 00:00:00
# 1406161  beijing_grid_001      115.0      39.1  2017-04-01 00:00:00
# 1406162  beijing_grid_002      115.0      39.2  2017-04-01 00:00:00
# 1406163  beijing_grid_003      115.0      39.3  2017-04-01 00:00:00
# 1406164  beijing_grid_004      115.0      39.4  2017-04-01 00:00:00
#
#          temperature  pressure  humidity  wind_direction  wind_speed/kph
# 1406160        10.55    980.06     28.80          307.92           12.59
# 1406161        10.31    974.89     28.83          307.06           12.61
# 1406162         9.58    959.35     28.91          304.48           12.65
# 1406163         8.85    943.82     29.00          301.94           12.73
# 1406164         7.65    926.03     30.24          305.52           13.15
